# %% [markdown]
# # <center> Fera formidável 4.14 - <i> A liga ternária leve mais cara do mundo </i>
# <b> Disciplina: </b> Redes Neurais e Algoritmos Genéticos <br>
# <b> Professor: </b> Daniel Cassar <br>
# <b> Semestre: </b> 2025.1 <br>
# <b> Alunos(as): </b> Gabriel Martins Sousa e Vitor Gabriel Dreveck <br>
# <b> RM: </b> 24036 e 24046<br>

# %% [markdown]
# ---

# %% [markdown]
# ## Introdução
#
# A fim de exercitar ainda mais nossas habilidades na aplicação de Algoritmos Genéticos, desenvolvemos um algoritmo que encontra uma liga de três elementos com a maior razão entre seu preço e seu peso atômico. Uma liga é um conjunto de diferentes elementos, feita a fim de formar um material com propriedades diferenciadas. Nesta atividade, a liga ternária foi definida da forma $xAyBzC$, sendo que $x + y + z = 100 g$. Além disso, temos que seguir algumas condições, como: $x ≥ 5$ g, $y ≥ 5$ g, $z ≥ 5$ g e “A”, “B” e “C” são elementos químicos diferentes. Nós utilizamos o preço e o peso atômico dado no problema e que estão nos dicionários abaixo. Para alcançar nosso objetivo, aproveitamos os operadores genéticos, como os de mutação e cruzamento, para gerar a liga que tiver o maior preço dentre os elementos possíveis, mas ainda sim, seja ponderada pelo seu peso atômico.
#
# Abaixo, temos os dicionários com as informações de preço e peso atômico dos elementos:

# %%
# preço em dólares por quilograma
preco = {
    "H": 1.39,
    "He": 24,
    "Li": 85.6,
    "Be": 857,
    "B": 3.68,
    "C": 0.122,
    "N": 0.14,
    "O": 0.154,
    "F": 2.16,
    "Ne": 240,
    "Na": 3.43,
    "Mg": 2.32,
    "Al": 1.79,
    "Si": 1.7,
    "P": 2.69,
    "S": 0.0926,
    "Cl": 0.082,
    "Ar": 0.931,
    "K": 13.6,
    "Ca": 2.35,
    "Sc": 3460,
    "Ti": 11.7,
    "V": 385,
    "Cr": 9.4,
    "Mn": 1.82,
    "Fe": 0.424,
    "Co": 32.8,
    "Ni": 13.9,
    "Cu": 6,
    "Zn": 2.55,
    "Ga": 148,
    "Ge": 1010,
    "As": 1.31,
    "Se": 21.4,
    "Br": 4.39,
    "Kr": 290,
    "Rb": 15500,
    "Sr": 6.68,
    "Y": 31,
    "Nb": 85.6,
    "Mo": 40.1,
    "Tc": 100000,
    "Ru": 10600,
    "Rh": 147000,
    "Pd": 49500,
    "Ag": 521,
    "Cd": 2.73,
    "In": 167,
    "Sn": 18.7,
    "Sb": 5.79,
    "Te": 63.5,
    "I": 35,
    "Xe": 1800,
    "Cs": 61800,
    "Ba": 0.275,
    "La": 4.92,
    "Ce": 4.71,
    "Pr": 103,
    "Nd": 57.5,
    "Pm": 460000,
    "Sm": 13.9,
    "Eu": 31.4,
    "Gd": 28.6,
    "Tb": 658,
    "Dy": 307,
    "Ho": 57.1,
    "Er": 26.4,
    "Tm": 3000,
    "Yb": 17.1,
    "Lu": 643,
    "Hf": 900,
    "Ta": 312,
    "W": 35.3,
    "Re": 4150,
    "Os": 12000,
    "Ir": 56200,
    "Pt": 27800,
    "Hg": 30.2,
    "Tl": 4200,
    "Pb": 2,
    "Bi": 6.36,
    "Po": 49200000000000,
    "Ac": 29000000000000,
    "Th": 287,
    "Pa": 280000,
    "U": 101,
    "Np": 660000,
    "Pu": 6490000,
    "Am": 750000,
    "Cm": 160000000000,
    "Bk": 185000000000,
    "Cf": 185000000000,
}

# peso atômico em gramas por mol
peso_atomico = {
    "H": 1.008,
    "He": 4.002602,
    "Li": 6.94,
    "Be": 9.0121831,
    "B": 10.81,
    "C": 12.011,
    "N": 14.007,
    "O": 15.999,
    "F": 18.998403163,
    "Ne": 20.1797,
    "Na": 22.98976928,
    "Mg": 24.305,
    "Al": 26.9815385,
    "Si": 28.085,
    "P": 30.973761998,
    "S": 32.06,
    "Cl": 35.45,
    "Ar": 39.948,
    "K": 39.0983,
    "Ca": 40.078,
    "Sc": 44.955908,
    "Ti": 47.867,
    "V": 50.9415,
    "Cr": 51.9961,
    "Mn": 54.938044,
    "Fe": 55.845,
    "Co": 58.933194,
    "Ni": 58.6934,
    "Cu": 63.546,
    "Zn": 65.38,
    "Ga": 69.723,
    "Ge": 72.63,
    "As": 74.921595,
    "Se": 78.971,
    "Br": 79.904,
    "Kr": 83.798,
    "Rb": 85.4678,
    "Sr": 87.62,
    "Y": 88.90584,
    "Nb": 92.90637,
    "Mo": 95.95,
    "Tc": 97.90721,
    "Ru": 101.07,
    "Rh": 102.9055,
    "Pd": 106.42,
    "Ag": 107.8682,
    "Cd": 112.414,
    "In": 114.818,
    "Sn": 118.71,
    "Sb": 121.76,
    "Te": 127.6,
    "I": 126.90447,
    "Xe": 131.293,
    "Cs": 132.90545196,
    "Ba": 137.327,
    "La": 138.90547,
    "Ce": 140.116,
    "Pr": 140.90766,
    "Nd": 144.242,
    "Pm": 144.91276,
    "Sm": 150.36,
    "Eu": 151.964,
    "Gd": 157.25,
    "Tb": 158.92535,
    "Dy": 162.5,
    "Ho": 164.93033,
    "Er": 167.259,
    "Tm": 168.93422,
    "Yb": 173.045,
    "Lu": 174.9668,
    "Hf": 178.49,
    "Ta": 180.94788,
    "W": 183.84,
    "Re": 186.207,
    "Os": 190.23,
    "Ir": 192.217,
    "Pt": 195.084,
    "Hg": 200.592,
    "Tl": 204.38,
    "Pb": 207.2,
    "Bi": 208.9804,
    "Po": 209.0,
    "Ac": 227.0,
    "Th": 232.0377,
    "Pa": 231.03588,
    "U": 238.02891,
    "Np": 237.0,
    "Pu": 244.0,
    "Am": 243.0,
    "Cm": 247.0,
    "Bk": 247.0,
    "Cf": 251.0,
}

# %% [markdown]
# Assim como na Fera Formidável 4.13, queremos assemelhar esse problema ao das **caixas não-binárias**, portanto vamos atribuir um valor numérico para cada elemento, armazenando as informações em um novo dicionário.

# %%
elementos = {}

for i, elemento in enumerate(preco.keys()):
    elementos[i] = (elemento, preco[elemento], peso_atomico[elemento])

elementos
# Out:
# {0: ('H', 1.39, 1.008),
#  1: ('He', 24, 4.002602),
#  2: ('Li', 85.6, 6.94),
#  3: ('Be', 857, 9.0121831),
#  4: ('B', 3.68, 10.81),
#  5: ('C', 0.122, 12.011),
#  6: ('N', 0.14, 14.007),
#  7: ('O', 0.154, 15.999),
#  8: ('F', 2.16, 18.998403163),
#  9: ('Ne', 240, 20.1797),
#  10: ('Na', 3.43, 22.98976928),
#  11: ('Mg', 2.32, 24.305),
#  12: ('Al', 1.79, 26.9815385),
#  13: ('Si', 1.7, 28.085),
#  14: ('P', 2.69, 30.973761998),
#  15: ('S', 0.0926, 32.06),
#  16: ('Cl', 0.082, 35.45),
#  17: ('Ar', 0.931, 39.948),
#  18: ('K', 13.6, 39.0983),
#  19: ('Ca', 2.35, 40.078),
#  20: ('Sc', 3460, 44.955908),
#  21: ('Ti', 11.7, 47.867),
#  22: ('V', 385, 50.9415),
#  23: ('Cr', 9.4, 51.9961),
#  24: ('Mn', 1.82, 54.938044),
#  25: ('Fe', 0.424, 55.845),
#  26: ('Co', 32.8, 58.933194),
#  27: ('Ni', 13.9, 58.6934),
#  28: ('Cu', 6, 63.546),
#  29: ('Zn', 2.55, 65.38),
#  30: ('Ga', 148, 69.723),
#  31: ('Ge', 1010, 72.63),
#  32: ('As', 1.31, 74.921595),
#  33: ('Se', 21.4, 78.971),
# ...

# %% [markdown]
# ## Resolução

# %% [markdown]
# Usamos funções de um *script* separado para serem nossos operadores, gerar nossa população e calcular nossa função objetivo

# %%
import random
from pprint import pprint

from funcoes_liga_ternaria_leve import populacao_liga_ternaria as cria_populacao
from funcoes_liga_ternaria_leve import funcao_objetivo_pop_liga_ternaria_leve as funcao_objetivo
from funcoes_liga_ternaria_leve import selecao_torneio_max as funcao_selecao
from funcoes_liga_ternaria_leve import cruzamento_liga_ternaria as funcao_cruzamento
from funcoes_liga_ternaria_leve import mutacao_liga_ternaria as funcao_mutacao

# %% [markdown]
# Vamos detalhar o que cada uma dessas funções faz:
# - `populacao_liga_ternaria`: Essa função cria a população para o nosso problema da liga ternária. O que ela faz é criar vários candidatos que seguem os critérios definidos no problema, como o peso total da liga ser 100g e os valores mínimos para cada elemento ser 5g. A estrutura de um candidato é uma lista na qual os três primeiros valores correspondem a massa daquele elemento na liga e os três últimos são os números inteiros que correspondem aos elementos no nosso dicionário.
#
# - `funcao_objetivo_pop_liga_ternaria`: Para esse problema, queremos encontrar uma boa razão entre o preço da liga e o peso dos elementos que ela é composta. Como queremos que a liga seja a mEssa função é calculada multiplicando a massa de cada elemento pelo seu preço, e em seguida somando o preço de todos os elementos da liga.ais cara e mais leve possível, queremos que essa razão seja a maior possível, portanto temos um problema de **maximização**. Nessa função, calculamos o preço total da liga, multiplicando a massa de cada elemento pelo seu preço, e em seguida somando o preço de todos os elementos da liga, e calculamos a soma dos pesos atômicos dos seus elementos constituintes. Ao final, dividimos o preço pelo peso($\frac{preço}{peso}$).
#
# - `selecao_torneio_max`: Usamos como operador de seleção o método de torneio para maximização, no qual ele irá pegar uma amostra de 3 indivíduos da nossa população e selecionar o que apresentar o melhor valor de *fitness*.
#
# - `cruzamento_liga_ternaria`: Na nossa função de cruzamento, como o indivíduo é formado por duas partes que não podem se misturar, o ponto de corte do cruzamento deve ser exatamente no meio do indivíduo. Com isso, há a troca dos elementos e das massas para cada um dos filhos.
#
# - `mutacao_liga_ternaria`: Para a nossa função de mutação, precisamos seguir a mesma lógica da operação de cruzamento, as duas metades do indivíduo são independentes uma da outra. Devido a isso, escolhemos criar um operador de mutação que sorteia se ele irá mutar as massas do indivíduo, ou algum de seus elementos. Caso ele mude as massas, todas elas são mudadas juntas, já que ao final elas precisam somar 100. Já se um elemento for mutado, eu sorteio um novo gene que ainda não esteja naquela liga.

# %% [markdown]
# Em seguida, vamos definir os parâmetros da evolução do nosso algoritmo.

# %%
TAMANHO_POPULACAO = 200
NUM_GERACOES = 10000
CHANCE_DE_CRUZAMENTO = 0.5
CHANCE_DE_MUTACAO = 0.05
TAMANHO_TORNEIO = 3

VALOR_MINIMO = 5
VALOR_MAXIMO = 90

# %% [markdown]
# Vamos conferir como é a nossa população.

# %%
populacao = cria_populacao(TAMANHO_POPULACAO, elementos, VALOR_MINIMO, VALOR_MAXIMO)
pprint(populacao)
# funcao_objetivo(populacao)

# %% [markdown]
# Está tudo certo com a população, então já podemos evoluir o nosso algoritmo genético para encontrar a liga leve mais cara:

# %%
hall_da_fama = []

for n in range(NUM_GERACOES):
    
    # Seleção
    fitness = funcao_objetivo(populacao, elementos)        
    selecionados = funcao_selecao(populacao, fitness, TAMANHO_TORNEIO)
    
    # Cruzamento
    proxima_geracao = []
    for pai, mae in zip(selecionados[::2], selecionados[1::2]):
        individuo1, individuo2 = funcao_cruzamento(pai, mae, CHANCE_DE_CRUZAMENTO)
        proxima_geracao.append(individuo1)
        proxima_geracao.append(individuo2)
    
    # Mutação
    funcao_mutacao(proxima_geracao, elementos, CHANCE_DE_MUTACAO, VALOR_MAXIMO, VALOR_MAXIMO)
    
    # Atualização do hall da fama
    fitness = funcao_objetivo(proxima_geracao, elementos)
        
    maior_fitness = max(fitness)
    indice = fitness.index(maior_fitness)
    hall_da_fama.append(proxima_geracao[indice])    
    
    # Encerramento
    populacao = proxima_geracao

# %% [markdown]
# Ao final das gerações que definimos, precisamos recuperar o melhor indivíduo encontrado e suas informações. Para isso, temos o código abaixo:

# %%
fitness = funcao_objetivo(hall_da_fama, elementos)
maior_fitness = max(fitness)
indice = fitness.index(maior_fitness)
melhor_individuo_observado = hall_da_fama[indice]

melhor_individuo_observado

preco_melhor_individuo = sum([(melhor_individuo_observado[i] / 1000) * elementos[melhor_individuo_observado[i+3]][1] for i in range(3)])
peso_melhor_individuo = sum([(melhor_individuo_observado[i] / 100) * elementos[melhor_individuo_observado[i+3]][2] for i in range(3)])

print(f"Melhor indivíduo: {melhor_individuo_observado}")
print(f"Preço: ${preco_melhor_individuo:.2f}")
print(f"Peso atômico: {peso_melhor_individuo:.2f} g/mol\n")
print("Composição:")

for i in range(3):
    print(f"{melhor_individuo_observado[i]}g de {elementos[melhor_individuo_observado[i+3]][0]}")
# Out:
# Melhor indivíduo: [90, 5, 5, 81, 1, 0]
# Preço: $4428000000000.13
# Peso atômico: 188.35 g/mol
#
# Composição:
# 90g de Po
# 5g de He
# 5g de H

# %% [markdown]
# Conseguimos encontrar a liga que queríamos! Ela possui um alto custo devido ao polônio, porém, os outros elementos, que influenciam pouco no preço total, são os elementos mais leves.

# %% [markdown]
# ## Conclusão
# Com a execução da atividade, conseguimos obter o resultado que queríamos, mas também exercitamos ainda mais a prática de Algoritmos Genéticos, contornando restrições e aprendendo como interpretar nosso problema para resolvê-lo adequadamente.
#
# ---
# ### Contribuição de cada membro
#
# **Gabriel Martins:** *Implementação* e Documentação.
#
# **Vitor Dreveck:** **Implementação** e Revisão.
#
# ---
#
# ## Referências
# - *ATP-303 GA 3.3 - Notebook caixas não-binárias.ipynb*. CASSAR, Daniel Roberto . Material de aula sobre o problema das caixas não-binárias
